# %%
import pandas as pd 
import numpy as np

# %%
pd.read_csv('./data/titanic.txt')
# Out:
#       row.names pclass  survived  \
# 0             1    1st         1
# 1             2    1st         0
# 2             3    1st         0
# 3             4    1st         0
# 4             5    1st         1
# 5             6    1st         1
# 6             7    1st         1
# 7             8    1st         0
# 8             9    1st         1
# 9            10    1st         0
# 10           11    1st         0
# 11           12    1st         1
# 12           13    1st         1
# 13           14    1st         1
# 14           15    1st         0
# 15           16    1st         1
# 16           17    1st         0
# 17           18    1st         0
# 18           19    1st         1
# 19           20    1st         1
# 20           21    1st         1
# 21           22    1st         0
# 22           23    1st         1
# 23           24    1st         1
# 24           25    1st         1
# 25           26    1st         0
# 26           27    1st         1
# ...

# %%
# 1.获取数据
data = pd.read_csv('./data/titanic.txt')
# 2.数据基本处理 处理年龄缺失值 数据集划分 划分训练集和测试集

# 3.特征工程 标准化  决策树量纲不会有影响  one_hot编码 得到哑变量矩阵

# 4.机器学习 选择决策树

# 5.模型评估 分类评估的指标 准确率 精确率 召回率 F1-score AUC曲线 等等 都可以来评估
